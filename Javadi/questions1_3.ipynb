# %%
import pandas as pd
import os

# %%
list_files = os.listdir("../")
list_files
# Out:
# ['.git',
#  'away_team.csv',
#  'away_team_score.csv',
#  'barqi',
#  'event.csv',
#  'final.ipynb',
#  'home_team.csv',
#  'home_team_score.csv',
#  'Javadi',
#  'moghimi',
#  'odds.csv',
#  'pbp.csv',
#  'power.csv',
#  'round.csv',
#  'season.csv',
#  'statistics.csv',
#  'time.csv',
#  'tournament.csv',
#  'venue.csv',
#  'votes.csv']

# %%
df = pd.read_csv("../home_team_score.csv")
df
# Out:
#        match_id  current_score  display_score  period_1  period_2  period_3  \
# 0      11974053            3.0            3.0       NaN       NaN       NaN
# 1      11974066            0.0            0.0       NaN       NaN       NaN
# 2      11998445            1.0            1.0       5.0       6.0       6.0
# 3      11998446            0.0            0.0       4.0       1.0       NaN
# 4      11998447            2.0            2.0       6.0       6.0       NaN
# ...         ...            ...            ...       ...       ...       ...
# 35159  12213482            2.0            2.0       6.0       6.0       NaN
# 35160  12213483            2.0            2.0       6.0       6.0       NaN
# 35161  12213484            2.0            2.0       6.0       6.0       NaN
# 35162  12213486            2.0            2.0       6.0       6.0       NaN
# 35163  12213803            2.0            2.0       6.0       6.0       NaN
#
# ...
